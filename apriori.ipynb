# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_excel('D:\STMIK PPKIA Pradnya Paramita\Semester 6\Konsep & Aplikasi  Data Mining/data.xls')

# %%
store_data.head()
# Out:
#   Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 0     Wine    Chips    Bread   Butter     Milk    Apple
# 1     Wine      NaN    Bread   Butter     Milk      NaN
# 2      NaN      NaN    Bread   Butter     Milk      NaN
# 3      NaN    Chips      NaN      NaN      NaN    Apple
# 4     Wine    Chips    Bread   Butter     Milk    Apple

# %%
store_data.tail()
# Out:
#    Barang 1 Barang 2 Barang 3 Barang 4 Barang 5 Barang 6
# 17      NaN    Chips      NaN   Butter     Milk    Apple
# 18     Wine    Chips    Bread   Butter     Milk    Apple
# 19     Wine      NaN    Bread   Butter     Milk    Apple
# 20     Wine    Chips    Bread      NaN     Milk    Apple
# 21      NaN    Chips      NaN      NaN      NaN      NaN

# %%
store_data.shape
# Out:
# (22, 6)

# %%
records = []
for i in range(0, 22):
    records.append([str(store_data.values[i,j]) for j in range(0,6)])

# %%
association_rules = apriori(records, min_support=0.10, min_confidence=0.7, min_lift=1.2, min_lenght=2)
association_results = list(association_rules)

# %%
print(len(association_results))
# Out:
# 24

# %%
print(association_results[0])
# Out:
# RelationRecord(items=frozenset({'Apple', 'Bread', 'Wine'}), support=0.45454545454545453, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Apple', 'Wine'}), items_add=frozenset({'Bread'}), confidence=0.9090909090909091, lift=1.25)])

# %%
results =[]
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:6]
    value3 = str(item[2][0][2])[:6]
    value4 = str(item[2][0][3])[:6]
    
    rows = (value0,value1,value2,value3,value4)
    
    results.append(rows)
    
    label = ['title1', 'title2','support','confidence','lift']
    
    store_suggestion = pd.DataFrame.from_records(results,columns=label)
    
    print(store_suggestion)
# Out:
#   title1 title2 support confidence  lift
# 0  Apple  Bread  0.4545     0.9090  1.25
#   title1  title2 support confidence    lift
# 0  Apple   Bread  0.4545     0.9090    1.25
# 1  Apple  Butter  0.4090     0.8181  1.2000
#   title1  title2 support confidence    lift
# 0  Apple   Bread  0.4545     0.9090    1.25
# 1  Apple  Butter  0.4090     0.8181  1.2000
# 2  Chips  Butter  0.4090     0.9000  1.3200
#    title1  title2 support confidence    lift
# 0   Apple   Bread  0.4545     0.9090    1.25
# 1   Apple  Butter  0.4090     0.8181  1.2000
# 2   Chips  Butter  0.4090     0.9000  1.3200
# 3  Butter   Bread     0.5     0.7333  1.2410
#    title1  title2 support confidence    lift
# 0   Apple   Bread  0.4545     0.9090    1.25
# 1   Apple  Butter  0.4090     0.8181  1.2000
# 2   Chips  Butter  0.4090     0.9000  1.3200
# 3  Butter   Bread     0.5     0.7333  1.2410
# 4  Butter   Bread  0.4545     0.9090    1.25
#    title1  title2 support confidence    lift
# ...

# %%
store_suggestion.describe()
# Out:
#        title1 title2 support confidence    lift
# count      24     24      24         24      24
# unique      4      5       9         13      17
# top     Apple  Chips  0.2272     0.7142  1.2087
# freq        8      6       6          3       3

# %%
store_suggestion.to_excel('D:\STMIK PPKIA Pradnya Paramita\Semester 6\Konsep & Aplikasi  Data Mining/data_output.xls')
